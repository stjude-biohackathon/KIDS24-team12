# %%
pip install -U langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 11.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 7.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run dragen-slayer/src/jessie_is_testing_things/Gdragon.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/notebooks/dragen-slayer/src/jessie_is_testing_things/Gdragon.py:7
#       5 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       6 from langchain.schema.document import Document
# ----> 7 from get_embedding_function import get_embedding_function
#       8 from langchain.vectorstores.chroma import Chroma
#      11 CHROMA_PATH = "chroma"
#
# ModuleNotFoundError: No module named 'get_embedding_function'

# %%
pip install -r dragen-slayer/src/jessie_is_testing_things/requirements.txt
# Out:
# ...
#   Using cached transformers-4.44.2-py3-none-any.whl (9.5 MB)
# ...
#   Using cached accelerate-0.33.0-py3-none-any.whl (315 kB)
# ...
#   Using cached peft-0.12.0-py3-none-any.whl (296 kB)
# ...
#   Using cached trl-0.9.6-py3-none-any.whl (245 kB)
# ...
#   Using cached gradio-4.42.0-py3-none-any.whl (16.8 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 41.4 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached einops-0.8.0-py3-none-any.whl (43 kB)
# ...
#   Using cached tiktoken-0.7.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# ...
#   Using cached uvicorn-0.30.6-py3-none-any.whl (62 kB)
# ...
#   Using cached fastapi-0.112.2-py3-none-any.whl (93 kB)
# ...
#   Using cached sse_starlette-2.1.3-py3-none-any.whl (9.4 kB)
# ...
#   Using cached matplotlib-3.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# ...
#   Using cached tokenizers-0.19.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# ...
#   Using cached huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# ...

# %%
# %run dragen-slayer/src/jessie_is_testing_things/Gdragon.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/notebooks/dragen-slayer/src/jessie_is_testing_things/Gdragon.py:7
#       5 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       6 from langchain.schema.document import Document
# ----> 7 from get_embedding_function import get_embedding_function
#       8 from langchain.vectorstores.chroma import Chroma
#      11 CHROMA_PATH = "chroma"
#
# ModuleNotFoundError: No module named 'get_embedding_function'

# %%
pip install get_embedding_function
# Out:
# ERROR: Could not find a version that satisfies the requirement get_embedding_function (from versions: none)
# ERROR: No matching distribution found for get_embedding_function
# Note: you may need to restart the kernel to use updated packages.
